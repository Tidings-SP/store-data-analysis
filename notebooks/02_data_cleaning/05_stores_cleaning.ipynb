# %% [markdown]
# # Stores Data Cleaning
# Clean and preprocess stores data

# %%
import pandas as pd
import sys
sys.path.append('../..')
from src.data_loader import load_data
from src.preprocessing import *
